# %%
# !ls
# Out:
# Corpus.ipynb		   taxidromikos_kodikas_data.csv
# greek_wikipedia_names.csv  taxidromikos_kodikas_data.ods

# %%
import pandas as pd

# %%
df = pd.read_csv("taxidromikos_kodikas_data.csv")

# %%
df
# Out:
#         Τ.Κ.             ΔΙΕΥΘΥΝΣΗ          ΑΡΙΘΜΟΙ            ΠΟΛΗ  \
# 0      10431  3ΗΣ (Γ') ΣΕΠΤΕΜΒΡΙΟΥ      1-3     2-4           ΑΘΗΝΑ
# 1      10431    ΑΓΙΟΥ ΚΩΝΣΤΑΝΤΙΝΟΥ     1-23    2-20           ΑΘΗΝΑ
# 2      10564  ΒΕΝΙΖΕΛΟΥ ΕΛΕΥΘΕΡΙΟΥ            1-ΤΕΛ           ΑΘΗΝΑ
# 3      10552              ΓΕΡΑΝΙΟΥ     1-27    2-30           ΑΘΗΝΑ
# 4      10431        ΔΕΒΕΡΙΚΟΥ ΣΤΟΑ              NaN           ΑΘΗΝΑ
# ...      ...                   ...              ...             ...
# 55395  16342       ΑΝΤΥΠΑ Μ. ΛΕΩΦ.  147-ΤΕΛ 154-ΤΕΛ       ΗΛΙΟΥΠΟΛΗ
# 55396  38221                  ΔΙΑΣ              NaN           ΒΟΛΟΣ
# 55397  15343           ΔΗΜΟΚΡΑΤΙΑΣ              NaN  ΑΓΙΑ ΠΑΡΑΣΚΕΥΗ
# 55398  10682                ΚΥΠΡΟΥ              NaN           ΑΘΗΝΑ
# 55399  22029                 ΤΥΡΟΣ              NaN             NaN
#
#            ΝΟΜΟΣ ΑΡΙΘΜΟΣ (ΜΟΝΑ) ΑΡΧΗ ΑΡΙΘΜΟΣ (ΜΟΝΑ) ΤΕΛΟΣ ΑΡΙΘΜΟΣ (ΖΥΓΑ) ΑΡΧΗ  \
# ...

# %% [markdown]
# # 1. GET useful information
# ## Poli & Nomo

# %%
df1 = df[['ΠΟΛΗ', 'ΝΟΜΟΣ', 'Τ.Κ.']]

# %%
df1
# Out:
#                  ΠΟΛΗ      ΝΟΜΟΣ   Τ.Κ.
# 0               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10431
# 1               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10431
# 2               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10564
# 3               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10552
# 4               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10431
# ...               ...        ...    ...
# 55395       ΗΛΙΟΥΠΟΛΗ    ΑΤΤΙΚΗΣ  16342
# 55396           ΒΟΛΟΣ  ΜΑΓΝΗΣΙΑΣ  38221
# 55397  ΑΓΙΑ ΠΑΡΑΣΚΕΥΗ    ΑΤΤΙΚΗΣ  15343
# 55398           ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10682
# 55399             NaN        NaN  22029
#
# [55400 rows x 3 columns]

# %% [markdown]
# # 2. Check and Drop NaN values

# %%
#!pip install missingno

# %%
#import missingno as msno
#%matplotlib inline

# %%
#msno.matrix(df1.sample(1000))

# %%
df1["ΠΟΛΗ"].isnull().sum()
# Out:
# 1

# %%
df1["ΝΟΜΟΣ"].isnull().sum()
# Out:
# 1

# %%
df1 = df1.dropna()

# %% [markdown]
# # create a dataframe column with "Place of Birth"
# # & "Dimotis"

# %%
df1
# Out:
#                  ΠΟΛΗ      ΝΟΜΟΣ   Τ.Κ.
# 0               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10431
# 1               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10431
# 2               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10564
# 3               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10552
# 4               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10431
# ...               ...        ...    ...
# 55394        ΖΩΓΡΑΦΟΣ    ΑΤΤΙΚΗΣ  15771
# 55395       ΗΛΙΟΥΠΟΛΗ    ΑΤΤΙΚΗΣ  16342
# 55396           ΒΟΛΟΣ  ΜΑΓΝΗΣΙΑΣ  38221
# 55397  ΑΓΙΑ ΠΑΡΑΣΚΕΥΗ    ΑΤΤΙΚΗΣ  15343
# 55398           ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10682
#
# [55399 rows x 3 columns]

# %%
# Place of Birth "Poli" + "Nomos"
df1['Place of Birth'] = df1[['ΠΟΛΗ', 'ΝΟΜΟΣ']].agg(' '.join, axis=1)
# Out:
# /tmp/ipykernel_28665/1387489123.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Place of Birth'] = df1[['ΠΟΛΗ', 'ΝΟΜΟΣ']].agg(' '.join, axis=1)

# %%
df1
# Out:
#                  ΠΟΛΗ      ΝΟΜΟΣ   Τ.Κ.          Place of Birth
# 0               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10431           ΑΘΗΝΑ ΑΤΤΙΚΗΣ
# 1               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10431           ΑΘΗΝΑ ΑΤΤΙΚΗΣ
# 2               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10564           ΑΘΗΝΑ ΑΤΤΙΚΗΣ
# 3               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10552           ΑΘΗΝΑ ΑΤΤΙΚΗΣ
# 4               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10431           ΑΘΗΝΑ ΑΤΤΙΚΗΣ
# ...               ...        ...    ...                     ...
# 55394        ΖΩΓΡΑΦΟΣ    ΑΤΤΙΚΗΣ  15771        ΖΩΓΡΑΦΟΣ ΑΤΤΙΚΗΣ
# 55395       ΗΛΙΟΥΠΟΛΗ    ΑΤΤΙΚΗΣ  16342       ΗΛΙΟΥΠΟΛΗ ΑΤΤΙΚΗΣ
# 55396           ΒΟΛΟΣ  ΜΑΓΝΗΣΙΑΣ  38221         ΒΟΛΟΣ ΜΑΓΝΗΣΙΑΣ
# 55397  ΑΓΙΑ ΠΑΡΑΣΚΕΥΗ    ΑΤΤΙΚΗΣ  15343  ΑΓΙΑ ΠΑΡΑΣΚΕΥΗ ΑΤΤΙΚΗΣ
# 55398           ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10682           ΑΘΗΝΑ ΑΤΤΙΚΗΣ
#
# [55399 rows x 4 columns]

# %%
# conert to str for concat
df1['Τ.Κ.'] = df1['Τ.Κ.'].astype(str) #.agg(' '.join, axis=1)
# Out:
# /tmp/ipykernel_28665/3637845936.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Τ.Κ.'] = df1['Τ.Κ.'].astype(str) #.agg(' '.join, axis=1)

# %%
df1
# Out:
#                  ΠΟΛΗ      ΝΟΜΟΣ   Τ.Κ.          Place of Birth
# 0               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10431           ΑΘΗΝΑ ΑΤΤΙΚΗΣ
# 1               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10431           ΑΘΗΝΑ ΑΤΤΙΚΗΣ
# 2               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10564           ΑΘΗΝΑ ΑΤΤΙΚΗΣ
# 3               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10552           ΑΘΗΝΑ ΑΤΤΙΚΗΣ
# 4               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10431           ΑΘΗΝΑ ΑΤΤΙΚΗΣ
# ...               ...        ...    ...                     ...
# 55394        ΖΩΓΡΑΦΟΣ    ΑΤΤΙΚΗΣ  15771        ΖΩΓΡΑΦΟΣ ΑΤΤΙΚΗΣ
# 55395       ΗΛΙΟΥΠΟΛΗ    ΑΤΤΙΚΗΣ  16342       ΗΛΙΟΥΠΟΛΗ ΑΤΤΙΚΗΣ
# 55396           ΒΟΛΟΣ  ΜΑΓΝΗΣΙΑΣ  38221         ΒΟΛΟΣ ΜΑΓΝΗΣΙΑΣ
# 55397  ΑΓΙΑ ΠΑΡΑΣΚΕΥΗ    ΑΤΤΙΚΗΣ  15343  ΑΓΙΑ ΠΑΡΑΣΚΕΥΗ ΑΤΤΙΚΗΣ
# 55398           ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10682           ΑΘΗΝΑ ΑΤΤΙΚΗΣ
#
# [55399 rows x 4 columns]

# %%
# Dimotis "Poli" + "T.K."
df1['Dimotis'] = df1[['ΠΟΛΗ', 'Τ.Κ.']].agg(' '.join, axis=1)
# Out:
# /tmp/ipykernel_28665/429204558.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Dimotis'] = df1[['ΠΟΛΗ', 'Τ.Κ.']].agg(' '.join, axis=1)

# %%
df1
# Out:
#                  ΠΟΛΗ      ΝΟΜΟΣ   Τ.Κ.       Place of Birth  \
# 0               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10431           ΑΘΗΝΑ10431
# 1               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10431           ΑΘΗΝΑ10431
# 2               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10564           ΑΘΗΝΑ10564
# 3               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10552           ΑΘΗΝΑ10552
# 4               ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10431           ΑΘΗΝΑ10431
# ...               ...        ...    ...                  ...
# 55394        ΖΩΓΡΑΦΟΣ    ΑΤΤΙΚΗΣ  15771        ΖΩΓΡΑΦΟΣ15771
# 55395       ΗΛΙΟΥΠΟΛΗ    ΑΤΤΙΚΗΣ  16342       ΗΛΙΟΥΠΟΛΗ16342
# 55396           ΒΟΛΟΣ  ΜΑΓΝΗΣΙΑΣ  38221           ΒΟΛΟΣ38221
# 55397  ΑΓΙΑ ΠΑΡΑΣΚΕΥΗ    ΑΤΤΙΚΗΣ  15343  ΑΓΙΑ ΠΑΡΑΣΚΕΥΗ15343
# 55398           ΑΘΗΝΑ    ΑΤΤΙΚΗΣ  10682           ΑΘΗΝΑ10682
#
#                     Dimotis
# 0               ΑΘΗΝΑ 10431
# 1               ΑΘΗΝΑ 10431
# 2               ΑΘΗΝΑ 10564
# 3               ΑΘΗΝΑ 10552
# 4               ΑΘΗΝΑ 10431
# ...                     ...
# ...

# %%
df1 = df1.sample(frac=1)

# %%
df1
# Out:
#               ΠΟΛΗ         ΝΟΜΟΣ   Τ.Κ.            Place of Birth  \
# 35834  ΘΕΣΣΑΛΟΝΙΚΗ  ΘΕΣΣΑΛΟΝΙΚΗΣ  54453  ΘΕΣΣΑΛΟΝΙΚΗ ΘΕΣΣΑΛΟΝΙΚΗΣ
# 3409         ΑΘΗΝΑ       ΑΤΤΙΚΗΣ  11632             ΑΘΗΝΑ ΑΤΤΙΚΗΣ
# 2808         ΑΘΗΝΑ       ΑΤΤΙΚΗΣ  11476             ΑΘΗΝΑ ΑΤΤΙΚΗΣ
# 12445     ΒΡΙΛΗΣΙΑ       ΑΤΤΙΚΗΣ  15235          ΒΡΙΛΗΣΙΑ ΑΤΤΙΚΗΣ
# 27134       ΛΑΡΙΣΑ       ΛΑΡΙΣΑΣ  41221            ΛΑΡΙΣΑ ΛΑΡΙΣΑΣ
# ...            ...           ...    ...                       ...
# 28368     ΗΡΑΚΛΕΙΟ     ΗΡΑΚΛΕΙΟΥ  71307        ΗΡΑΚΛΕΙΟ ΗΡΑΚΛΕΙΟΥ
# 46178        ΝΕΜΕΑ     ΚΟΡΙΝΘΙΑΣ  20500           ΝΕΜΕΑ ΚΟΡΙΝΘΙΑΣ
# 49609     ΚΟΜΟΤΗΝΗ       ΡΟΔΟΠΗΣ  69100          ΚΟΜΟΤΗΝΗ ΡΟΔΟΠΗΣ
# 33202        ΠΑΤΡΑ        ΑΧΑΙΑΣ  26333              ΠΑΤΡΑ ΑΧΑΙΑΣ
# 51985      ΒΟΛΙΜΕΣ      ΖΑΚΥΝΘΟΥ  29091          ΒΟΛΙΜΕΣ ΖΑΚΥΝΘΟΥ
#
#                  Dimotis
# 35834  ΘΕΣΣΑΛΟΝΙΚΗ 54453
# 3409         ΑΘΗΝΑ 11632
# 2808         ΑΘΗΝΑ 11476
# 12445     ΒΡΙΛΗΣΙΑ 15235
# 27134       ΛΑΡΙΣΑ 41221
# ...

# %%
#save to csv
name = 'taxydromikos_kwdikas.csv'
df1.to_csv(name, encoding='utf-8')

# %% [markdown]
# # conlusion

# %% [markdown]
# ### έχουμε τα πεδία "Δημότης" και "Αρχή Έκδοσης Δελτίου"

# %% [markdown]
# # Names Preprocessing

# %%
Names = pd.read_csv("greek_wikipedia_names.csv")

# %%
Names = Names.drop(["Unnamed: 0"], axis=1)

# %%
Names
# Out:
#                            Names
# 0                      AJ Ginnis
# 1             Achille Papapetrou
# 2         Achilleas Angelopoulos
# 3     Achilleas Grammatikopoulos
# 4             Adam Tzanetopoulos
# ...                          ...
# 1796                Zisis Tsekos
# 1797         Zoe Konstantopoulou
# 1798                 Zoe Zeniodi
# 1799              Zoi Dimitrakou
# 1800                 Şerif Gören
#
# [1801 rows x 1 columns]

# %%
# split column Parents to get beter results  
df_tmp = pd.DataFrame(Names['Names'].str.split(" ", 1).tolist(), columns=["Given Name", "Surname"])    
Names = pd.concat([Names, df_tmp], axis=1).drop(["Names"], axis=1)

# %%
# split column Parents to get beter results  
df_tmp = pd.DataFrame(Names['Surname'].str.split(" ", 1).tolist(), columns=["Second Name", "Surname2"])    
Names = pd.concat([Names, df_tmp], axis=1).drop(["Surname"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6599/3394172345.py in <module>
#       1 # split column Parents to get beter results
# ----> 2 df_tmp = pd.DataFrame(Names['Surname'].str.split(" ", 1).tolist(), columns=["Second Name", "Surname2"])
#       3 Names = pd.concat([Names, df_tmp], axis=1).drop(["Surname"], axis=1)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     692                         # ndarray], Index, Series], Sequence[Any]]"
#     693                         columns = ensure_index(columns)  # type: ignore[arg-type]
# --> 694                     arrays, columns, index = nested_data_to_arrays(
#     695                         # error: Argument 3 to "nested_data_to_arrays" has incompatible
# ...

# %%
Names[20:40]
# Out:
#     Given Name          Surname
# 20      Alekos        Alexiadis
# 21      Alekos        Fassianos
# 22      Alekos        Petroulas
# 23        Alex   Andrianopoulos
# 24        Alex            Binas
# 25   Alexander        Voulgaris
# 26   Alexandra          Asimaki
# 27   Alexandra         Diplarou
# 28   Alexandra      Filia Kelly
# 29   Alexandra          Ordolis
# 30  Alexandros      Abdel Rahim
# 31  Alexandros        Alexiadis
# 32  Alexandros   Apostolopoulos
# 33  Alexandros          Avranas
# 34  Alexandros            Binas
# 35  Alexandros       Christofis
# 36  Alexandros  Evgenios Gounas
# 37  Alexandros           Gounas
# 38  Alexandros      Hatzipetros
# 39  Alexandros      Karachalios

# %%
    # remove whitespaces from those columns
    df["Mother's Parents"] = df["Mother's Parents"].str.strip()
    df["Father's Parents"] = df["Father's Parents"].str.strip()
